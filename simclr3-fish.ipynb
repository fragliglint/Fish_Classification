# %%
# !pip install lightly
# Out:
# Collecting lightly
#   Downloading lightly-1.5.22-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from lightly) (2025.6.15)
# Collecting hydra-core>=1.0.0 (from lightly)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightly_utils~=0.0.0 (from lightly)
#   Downloading lightly_utils-0.0.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from lightly) (1.26.4)
# Requirement already satisfied: python_dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from lightly) (2.9.0.post0)
# Requirement already satisfied: requests>=2.27.0 in /usr/local/lib/python3.11/dist-packages (from lightly) (2.32.4)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from lightly) (1.17.0)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.11/dist-packages (from lightly) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from lightly) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from lightly) (0.21.0+cu124)
# Requirement already satisfied: pydantic>=1.10.5 in /usr/local/lib/python3.11/dist-packages (from lightly) (2.11.7)
# Requirement already satisfied: pytorch_lightning>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from lightly) (2.5.2)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.11/dist-packages (from lightly) (2.5.0)
# Collecting aenum>=3.1.11 (from lightly)
#   Downloading aenum-3.1.16-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.0.0->lightly) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.0.0->lightly) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.0.0->lightly) (25.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from lightly_utils~=0.0.0->lightly) (11.2.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->lightly) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->lightly) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->lightly) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->lightly) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->lightly) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->lightly) (2.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.10.5->lightly) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.10.5->lightly) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.10.5->lightly) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.10.5->lightly) (0.4.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning>=1.0.4->lightly) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (2025.5.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning>=1.0.4->lightly) (1.7.3)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning>=1.0.4->lightly) (0.14.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.0->lightly) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.0->lightly) (3.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->lightly) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->lightly) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->lightly) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->lightly)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->lightly)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->lightly)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->lightly)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->lightly)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->lightly)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->lightly)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->lightly)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->lightly)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->lightly) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->lightly) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->lightly) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->lightly)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->lightly) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->lightly) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->lightly) (1.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (3.12.13)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning>=1.0.4->lightly) (75.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->lightly) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->lightly) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->lightly) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.1->lightly) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.1->lightly) (2024.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (1.20.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.1->lightly) (2024.2.0)
# Downloading lightly-1.5.22-py3-none-any.whl (859 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.3/859.3 kB 27.3 MB/s eta 0:00:00
# Downloading aenum-3.1.16-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 7.5 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.6 MB/s eta 0:00:00
# Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 95.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 51.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.6 MB/s eta 0:00:00
# Installing collected packages: aenum, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, hydra-core, nvidia-cusolver-cu12, lightly_utils, lightly
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed aenum-3.1.16 hydra-core-1.3.2 lightly-1.5.22 lightly_utils-0.0.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# ============================
# Full SimCLR Pipeline (like MoCo)
# ============================

import os, shutil, random
from glob import glob
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from lightly.loss import NTXentLoss

device = "cuda" if torch.cuda.is_available() else "cpu"

# -----------------------------
# 1️⃣ Dataset split (Raw + Raw Data only)
# -----------------------------
root_dir = "/kaggle/input/fish-classification-dataset/Fish Data/Fish Data"
working_dir = "/kaggle/working/fish_dataset_split_simclr"

train_ratio, val_ratio, test_ratio = 0.7, 0.15, 0.15
splits = ["train", "val", "test"]

os.makedirs(working_dir, exist_ok=True)
for s in splits:
    os.makedirs(os.path.join(working_dir, s), exist_ok=True)

# Only split if empty
needs_split = any(len(os.listdir(os.path.join(working_dir, s))) == 0 for s in splits)

if needs_split:
    for cls in os.listdir(root_dir):
        class_dir = os.path.join(root_dir, cls)
        if not os.path.isdir(class_dir):
            continue
        raw_folders = ["Raw", "Raw Data"]
        images = []
        for rf in raw_folders:
            path = os.path.join(class_dir, rf)
            if os.path.exists(path):
                images.extend([p for p in glob(os.path.join(path, "*")) if os.path.isfile(p)])
        if len(images) == 0:
            continue

        random.shuffle(images)
        n = len(images)
        n_train = int(n * train_ratio)
        n_val = int(n * val_ratio)
        n_test = n - n_train - n_val

        assigns = {
            "train": images[:n_train],
            "val": images[n_train:n_train + n_val],
            "test": images[n_train + n_val:]
        }

        for s in splits:
            dest_dir = os.path.join(working_dir, s, cls)
            os.makedirs(dest_dir, exist_ok=True)
            for p in assigns[s]:
                try:
                    shutil.copy(p, dest_dir)
                except:
                    pass
    print("✅ Dataset split created in:", working_dir)
else:
    print("ℹ️ Using existing split in:", working_dir)
# Out:
# ✅ Dataset split created in: /kaggle/working/fish_dataset_split_simclr

# %%
# -----------------------------
# 2️⃣ Pretraining Dataset + Augmentations
# -----------------------------
simclr_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.8, 0.8, 0.8, 0.2),
    transforms.RandomGrayscale(p=0.2),
    transforms.GaussianBlur(kernel_size=3),
    transforms.ToTensor(),
])

train_dataset = datasets.ImageFolder(os.path.join(working_dir, "train"), transform=simclr_transform)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, drop_last=True)

# -----------------------------
# 3️⃣ Backbone + Projection Head
# -----------------------------
backbone = models.resnet18(pretrained=False)
backbone.fc = nn.Identity()

class SimCLR(nn.Module):
    def __init__(self, backbone, num_ftrs=512, projection_dim=128):
        super().__init__()
        self.backbone = backbone
        self.projection = nn.Sequential(
            nn.Linear(num_ftrs, 512),
            nn.ReLU(),
            nn.Linear(512, projection_dim)
        )

    def forward(self, x):
        h = self.backbone(x)
        z = self.projection(h)
        return z

model = SimCLR(backbone).to(device)
criterion = NTXentLoss(temperature=0.5)
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

# -----------------------------
# 4️⃣ SimCLR Pretraining
# -----------------------------
epochs_pre = 100
for epoch in range(epochs_pre):
    total_loss = 0
    model.train()
    for images, _ in train_loader:
        x0 = images.to(device)
        x1 = images.to(device)

        z0 = model(x0)
        z1 = model(x1)

        loss = criterion(z0, z1)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch [{epoch+1}/{epochs_pre}], SimCLR Loss: {total_loss/len(train_loader):.4f}")

torch.save(backbone.state_dict(), "simclr_backbone.pth")
print("✅ SimCLR pretraining finished and backbone saved!")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch [1/100], SimCLR Loss: 3.0076
# Epoch [2/100], SimCLR Loss: 2.9393
# Epoch [3/100], SimCLR Loss: 2.9288
# Epoch [4/100], SimCLR Loss: 2.9248
# Epoch [5/100], SimCLR Loss: 2.9225
# Epoch [6/100], SimCLR Loss: 2.9191
# Epoch [7/100], SimCLR Loss: 2.9190
# Epoch [8/100], SimCLR Loss: 2.9150
# Epoch [9/100], SimCLR Loss: 2.9144
# Epoch [10/100], SimCLR Loss: 2.9131
# Epoch [11/100], SimCLR Loss: 2.9118
# Epoch [12/100], SimCLR Loss: 2.9103
# Epoch [13/100], SimCLR Loss: 2.9092
# Epoch [14/100], SimCLR Loss: 2.9095
# Epoch [15/100], SimCLR Loss: 2.9079
# Epoch [16/100], SimCLR Loss: 2.9101
# Epoch [17/100], SimCLR Loss: 2.9123
# Epoch [18/100], SimCLR Loss: 2.9069
# Epoch [19/100], SimCLR Loss: 2.9055
# Epoch [20/100], SimCLR Loss: 2.9040
# Epoch [21/100], SimCLR Loss: 2.9035
# Epoch [22/100], SimCLR Loss: 2.9042
# Epoch [23/100], SimCLR Loss: 2.9024
# Epoch [24/100], SimCLR Loss: 2.9020
# Epoch [25/100], SimCLR Loss: 2.9030
# Epoch [26/100], SimCLR Loss: 2.9024
# Epoch [27/100], SimCLR Loss: 2.9013
# Epoch [28/100], SimCLR Loss: 2.8989
# Epoch [29/100], SimCLR Loss: 2.8977
# Epoch [30/100], SimCLR Loss: 2.8984
# Epoch [31/100], SimCLR Loss: 2.8982
# Epoch [32/100], SimCLR Loss: 2.8965
# Epoch [33/100], SimCLR Loss: 2.8958
# Epoch [34/100], SimCLR Loss: 2.8961
# Epoch [35/100], SimCLR Loss: 2.8954
# Epoch [36/100], SimCLR Loss: 2.8943
# Epoch [37/100], SimCLR Loss: 2.8939
# Epoch [38/100], SimCLR Loss: 2.8931
# Epoch [39/100], SimCLR Loss: 2.8935
# Epoch [40/100], SimCLR Loss: 2.8916
# Epoch [41/100], SimCLR Loss: 2.8916
# Epoch [42/100], SimCLR Loss: 2.8932
# Epoch [43/100], SimCLR Loss: 2.8926
# Epoch [44/100], SimCLR Loss: 2.8906
# Epoch [45/100], SimCLR Loss: 2.8905
# Epoch [46/100], SimCLR Loss: 2.8898
# Epoch [47/100], SimCLR Loss: 2.8897
# Epoch [48/100], SimCLR Loss: 2.8889
# Epoch [49/100], SimCLR Loss: 2.8883
# Epoch [50/100], SimCLR Loss: 2.8873
# Epoch [51/100], SimCLR Loss: 2.8868
# Epoch [52/100], SimCLR Loss: 2.8869
# Epoch [53/100], SimCLR Loss: 2.8874
# Epoch [54/100], SimCLR Loss: 2.8868
# Epoch [55/100], SimCLR Loss: 2.8859
# Epoch [56/100], SimCLR Loss: 2.8857
# Epoch [57/100], SimCLR Loss: 2.8847
# Epoch [58/100], SimCLR Loss: 2.8882
# Epoch [59/100], SimCLR Loss: 2.8873
# Epoch [60/100], SimCLR Loss: 2.8855
# Epoch [61/100], SimCLR Loss: 2.8847
# Epoch [62/100], SimCLR Loss: 2.8841
# Epoch [63/100], SimCLR Loss: 2.8833
# Epoch [64/100], SimCLR Loss: 2.8859
# Epoch [65/100], SimCLR Loss: 2.8840
# Epoch [66/100], SimCLR Loss: 2.8831
# Epoch [67/100], SimCLR Loss: 2.8822
# Epoch [68/100], SimCLR Loss: 2.8815
# Epoch [69/100], SimCLR Loss: 2.8816
# Epoch [70/100], SimCLR Loss: 2.8825
# Epoch [71/100], SimCLR Loss: 2.8813
# Epoch [72/100], SimCLR Loss: 2.8808
# Epoch [73/100], SimCLR Loss: 2.8818
# Epoch [74/100], SimCLR Loss: 2.8802
# Epoch [75/100], SimCLR Loss: 2.8807
# Epoch [76/100], SimCLR Loss: 2.8808
# Epoch [77/100], SimCLR Loss: 2.8801
# Epoch [78/100], SimCLR Loss: 2.8795
# Epoch [79/100], SimCLR Loss: 2.8792
# Epoch [80/100], SimCLR Loss: 2.8792
# Epoch [81/100], SimCLR Loss: 2.8794
# Epoch [82/100], SimCLR Loss: 2.8783
# Epoch [83/100], SimCLR Loss: 2.8781
# Epoch [84/100], SimCLR Loss: 2.8784
# Epoch [85/100], SimCLR Loss: 2.8795
# Epoch [86/100], SimCLR Loss: 2.8779
# Epoch [87/100], SimCLR Loss: 2.8783
# Epoch [88/100], SimCLR Loss: 2.8780
# Epoch [89/100], SimCLR Loss: 2.8772
# Epoch [90/100], SimCLR Loss: 2.8766
# Epoch [91/100], SimCLR Loss: 2.8772
# Epoch [92/100], SimCLR Loss: 2.8777
# Epoch [93/100], SimCLR Loss: 2.8781
# Epoch [94/100], SimCLR Loss: 2.8767
# Epoch [95/100], SimCLR Loss: 2.8772
# Epoch [96/100], SimCLR Loss: 2.8767
# Epoch [97/100], SimCLR Loss: 2.8781
# Epoch [98/100], SimCLR Loss: 2.8776
# Epoch [99/100], SimCLR Loss: 2.8770
# Epoch [100/100], SimCLR Loss: 2.8765
# ✅ SimCLR pretraining finished and backbone saved!

# %%
# -----------------------------
# 5️⃣ Fine-tuning (like BYOL/MoCo)
# -----------------------------
finetune_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])

train_dataset_ft = datasets.ImageFolder(os.path.join(working_dir, "train"), transform=finetune_transform)
val_dataset_ft   = datasets.ImageFolder(os.path.join(working_dir, "val"),   transform=finetune_transform)
test_dataset_ft  = datasets.ImageFolder(os.path.join(working_dir, "test"),  transform=finetune_transform)

train_loader_ft = DataLoader(train_dataset_ft, batch_size=64, shuffle=True)
val_loader_ft   = DataLoader(val_dataset_ft, batch_size=64, shuffle=False)
test_loader_ft  = DataLoader(test_dataset_ft, batch_size=64, shuffle=False)

# Freeze most backbone, unfreeze last 2 layers
for name, param in backbone.named_parameters():
    param.requires_grad = False
    if "layer3" in name or "layer4" in name:
        param.requires_grad = True
backbone.to(device)

num_classes = len(train_dataset_ft.classes)
classifier = nn.Linear(512, num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer_cls = torch.optim.Adam(
    list(classifier.parameters()) +
    [p for p in backbone.parameters() if p.requires_grad],
    lr=1e-4
)
epochs_cls = 50

for epoch in range(epochs_cls):
    classifier.train()
    total_loss = 0
    total_correct = 0

    for images, labels in train_loader_ft:
        images, labels = images.to(device), labels.to(device)
        features = backbone(images)
        outputs = classifier(features)
        loss = criterion(outputs, labels)

        optimizer_cls.zero_grad()
        loss.backward()
        optimizer_cls.step()

        total_loss += loss.item()
        total_correct += (outputs.argmax(1) == labels).sum().item()

    train_acc = total_correct / len(train_dataset_ft)
    print(f"Epoch [{epoch+1}/{epochs_cls}], Loss: {total_loss/len(train_loader_ft):.4f}, Train Acc: {train_acc:.4f}")

    # Validation
    classifier.eval()
    total_correct = 0
    with torch.no_grad():
        for images, labels in val_loader_ft:
            images, labels = images.to(device), labels.to(device)
            features = backbone(images)
            outputs = classifier(features)
            total_correct += (outputs.argmax(1) == labels).sum().item()
    val_acc = total_correct / len(val_dataset_ft)
# Out:
# Epoch [1/50], Loss: 2.2025, Train Acc: 0.3584
# Epoch [2/50], Loss: 1.2753, Train Acc: 0.6230
# Epoch [3/50], Loss: 0.8377, Train Acc: 0.7532
# Epoch [4/50], Loss: 0.5968, Train Acc: 0.8252
# Epoch [5/50], Loss: 0.4390, Train Acc: 0.8739
# Epoch [6/50], Loss: 0.3521, Train Acc: 0.8980
# Epoch [7/50], Loss: 0.2862, Train Acc: 0.9173
# Epoch [8/50], Loss: 0.2392, Train Acc: 0.9323
# Epoch [9/50], Loss: 0.1938, Train Acc: 0.9450
# Epoch [10/50], Loss: 0.1625, Train Acc: 0.9553
# Epoch [11/50], Loss: 0.1364, Train Acc: 0.9628
# Epoch [12/50], Loss: 0.1208, Train Acc: 0.9669
# Epoch [13/50], Loss: 0.1046, Train Acc: 0.9708
# Epoch [14/50], Loss: 0.0923, Train Acc: 0.9753
# Epoch [15/50], Loss: 0.0789, Train Acc: 0.9785
# Epoch [16/50], Loss: 0.0724, Train Acc: 0.9798
# Epoch [17/50], Loss: 0.0634, Train Acc: 0.9824
# Epoch [18/50], Loss: 0.0542, Train Acc: 0.9850
# Epoch [19/50], Loss: 0.0500, Train Acc: 0.9873
# Epoch [20/50], Loss: 0.0497, Train Acc: 0.9870
# Epoch [21/50], Loss: 0.0426, Train Acc: 0.9883
# Epoch [22/50], Loss: 0.0390, Train Acc: 0.9891
# Epoch [23/50], Loss: 0.0423, Train Acc: 0.9885
# Epoch [24/50], Loss: 0.0376, Train Acc: 0.9886
# Epoch [25/50], Loss: 0.0351, Train Acc: 0.9898
# Epoch [26/50], Loss: 0.0358, Train Acc: 0.9898
# Epoch [27/50], Loss: 0.0323, Train Acc: 0.9908
# Epoch [28/50], Loss: 0.0286, Train Acc: 0.9919
# Epoch [29/50], Loss: 0.0249, Train Acc: 0.9932
# Epoch [30/50], Loss: 0.0228, Train Acc: 0.9941
# Epoch [31/50], Loss: 0.0238, Train Acc: 0.9941
# Epoch [32/50], Loss: 0.0230, Train Acc: 0.9940
# Epoch [33/50], Loss: 0.0252, Train Acc: 0.9928
# Epoch [34/50], Loss: 0.0229, Train Acc: 0.9933
# Epoch [35/50], Loss: 0.0210, Train Acc: 0.9938
# Epoch [36/50], Loss: 0.0202, Train Acc: 0.9945
# Epoch [37/50], Loss: 0.0162, Train Acc: 0.9957
# Epoch [38/50], Loss: 0.0205, Train Acc: 0.9944
# Epoch [39/50], Loss: 0.0201, Train Acc: 0.9940
# Epoch [40/50], Loss: 0.0186, Train Acc: 0.9946
# Epoch [41/50], Loss: 0.0188, Train Acc: 0.9947
# Epoch [42/50], Loss: 0.0140, Train Acc: 0.9953
# Epoch [43/50], Loss: 0.0190, Train Acc: 0.9945
# Epoch [44/50], Loss: 0.0134, Train Acc: 0.9968
# Epoch [45/50], Loss: 0.0166, Train Acc: 0.9954
# Epoch [46/50], Loss: 0.0145, Train Acc: 0.9959
# Epoch [47/50], Loss: 0.0117, Train Acc: 0.9964
# Epoch [48/50], Loss: 0.0124, Train Acc: 0.9963
# Epoch [49/50], Loss: 0.0174, Train Acc: 0.9945
# Epoch [50/50], Loss: 0.0181, Train Acc: 0.9945

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, auc
import torch
import torch.nn.functional as F

backbone.eval()
classifier.eval()

all_labels = []
all_preds = []
all_probs = []

with torch.no_grad():
    for images, labels in test_loader_ft:
        images, labels = images.to(device), labels.to(device)
        features = backbone(images)
        outputs = classifier(features)

        probs = F.softmax(outputs, dim=1)
        preds = outputs.argmax(1)

        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

# -----------------------------
# 1️⃣ Test Accuracy
# -----------------------------
test_acc = (torch.tensor(all_preds) == torch.tensor(all_labels)).float().mean().item()
print(f"✅ Test Accuracy: {test_acc:.4f}")

# -----------------------------
# 2️⃣ Confusion Matrix
# -----------------------------
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - SimCLR")
plt.show()

# -----------------------------
# 3️⃣ ROC-AUC Curve (One-vs-Rest for multi-class)
# -----------------------------
from sklearn.preprocessing import label_binarize
import numpy as np

num_classes = len(train_dataset_ft.classes)
y_true_bin = label_binarize(all_labels, classes=list(range(num_classes)))
y_probs = np.array(all_probs)

plt.figure(figsize=(10, 8))
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {i} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - SimCLR")
plt.legend()
plt.show()

# -----------------------------
# 4️⃣ Macro ROC-AUC Score
# -----------------------------
macro_auc = roc_auc_score(y_true_bin, y_probs, average="macro")
print(f"✅ Macro ROC-AUC: {macro_auc:.4f}")
# Out:
# ✅ Test Accuracy: 0.8747
# ✅ Macro ROC-AUC: 0.9951

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch

def plot_tsne(backbone, dataloader, class_names, n_samples=2000):
    backbone.eval()
    features, labels = [], []

    with torch.no_grad():
        for imgs, lbls in dataloader:
            imgs = imgs.to(device)
            feats = backbone(imgs)
            features.append(feats.cpu().numpy())
            labels.append(lbls.numpy())
            if sum(len(l) for l in labels) >= n_samples:
                break

    features = np.concatenate(features, axis=0)[:n_samples]
    labels = np.concatenate(labels, axis=0)[:n_samples]

    tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=1000)
    embeddings = tsne.fit_transform(features)

    plt.figure(figsize=(10, 8))
    sns.scatterplot(
        x=embeddings[:, 0], y=embeddings[:, 1],
        hue=[class_names[l] for l in labels],
        palette="tab10", s=30, alpha=0.8
    )
    plt.title("t-SNE Clustering of Features (SimCLR Backbone)")
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt

def plot_tsne_simclr(backbone, dataloader, class_names, n_samples=2000):
    """
    Plot t-SNE visualization of features from a SimCLR-pretrained backbone.
    Uses only the backbone (not the projection head).
    """
    backbone.eval()
    feats, labels = [], []

    with torch.no_grad():
        for images, lbls in dataloader:
            images = images.to(device)
            f = backbone(images).cpu().numpy()   # ✅ backbone features only
            feats.append(f)
            labels.extend(lbls.numpy())
            if len(labels) >= n_samples:
                break

    feats = np.concatenate(feats, axis=0)[:n_samples]
    labels = np.array(labels)[:n_samples]

    tsne = TSNE(n_components=2, perplexity=30, n_iter=1000, random_state=42)
    feats_2d = tsne.fit_transform(feats)

    plt.figure(figsize=(12, 10))
    scatter = plt.scatter(
        feats_2d[:, 0], feats_2d[:, 1],
        c=labels, cmap="tab20", alpha=0.7, s=20
    )
    plt.legend(
        handles=scatter.legend_elements()[0],
        labels=class_names,
        bbox_to_anchor=(1.05, 1), loc='upper left'
    )
    plt.title("t-SNE Clustering of SimCLR Features")
    plt.show()
